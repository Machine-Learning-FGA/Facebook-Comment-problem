# %% [markdown]
# ## Informações sobre o dataset
#
#   O dataset provém do repositório de aprendizado de máquina da universidade X. Como dito anteriormente, o problema se trata de análise de dados a respeito de comentários no Facebook. Para solucionar tal problema, foram reunidos dados de grupos e páginas públicas como postagens de administradores dos mesmos e a quantidade de seus respectivos comentários.
#   A base de dados vem inicialmente, vem em um arquivo em formato .Zip. Onde, neste, está contido todo o volume de dados já dividido em partes voltadas para treinos e testes de algoritmos de aprendizagem de máquina.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingRegressor

# %%
cols = range(53)

# %%
# test1 = pd.read_csv('facebook_general_dataset/Dataset/Training/Features_Variant_1.csv', delimiter=',', usecols=cols)

# target1 = pd.read_csv('facebook_general_dataset/Dataset/Testing/Features_TestSet.csv', delimiter=',', usecols=[53])

# %%
gb = GradientBoostingRegressor(n_estimators=100000, min_samples_split=5, random_state=42)

# %%
test2 = pd.read_csv('facebook_general_dataset/Dataset/Training/Features_Variant_1.csv', header=None)

dataset_x = test2.iloc[:, :-1].values
dataset_y = test2.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset_x,dataset_y, 
                                                    test_size = 0.25, random_state=0)

# %%
gb.fit(X_train, y_train)
y_pred = gb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-b9afc94442c9> in <module>()
# ----> 1 gb.fit(X_train, y_train)
#       2 y_pred = gb.predict(X_test)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in fit(self, X, y, sample_weight, monitor)
#    1032         # fit the boosting stages
#    1033         n_stages = self._fit_stages(X, y, y_pred, sample_weight, random_state,
# -> 1034                                     begin_at_stage, monitor, X_idx_sorted)
#    1035         # change shape of arrays after fit (early-stopping or additional ests)
#    1036         if n_stages != self.estimators_.shape[0]:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _fit_stages(self, X, y, y_pred, sample_weight, random_state, begin_at_stage, monitor, X_idx_sorted)
#    1087             y_pred = self._fit_stage(i, X, y, y_pred, sample_weight,
#    1088                                      sample_mask, random_state, X_idx_sorted,
# -> 1089                                      X_csc, X_csr)
#    1090
#    1091             # track deviance (= loss)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/gradient_boosting.py in _fit_stage(self, i, X, y, y_pred, sample_weight, sample_mask, random_state, X_idx_sorted, X_csc, X_csr)
#     786             else:
#     787                 tree.fit(X, residual, sample_weight=sample_weight,
# --> 788                          check_input=False, X_idx_sorted=X_idx_sorted)
#     789
#     790             # update tree leaves
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1122             sample_weight=sample_weight,
#    1123             check_input=check_input,
# -> 1124             X_idx_sorted=X_idx_sorted)
#    1125         return self
#    1126
#
# /anaconda3/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     360                                            min_impurity_split)
#     361
# --> 362         builder.build(self.tree_, X, y, sample_weight, X_idx_sorted)
#     363
#     364         if self.n_outputs_ == 1:
#
# KeyboardInterrupt:

# %%
y_pred = gb.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

mean_absolute_error(y_test, y_pred)
mean_squared_error(y_test, y_pred)
# Out:
# 0.30468783928013726

# %%
test1.describe()
# Out:
#              634995              0           463             1           0.0  \
# count  4.094800e+04   40948.000000  4.094800e+04  40948.000000  40948.000000
# mean   1.313830e+06    4676.247949  4.480133e+04     24.255348      1.586280
# std    6.785834e+06   20593.423357  1.109349e+05     19.950496     20.753426
# min    3.600000e+01       0.000000  0.000000e+00      1.000000      0.000000
# 25%    3.673400e+04       0.000000  6.980000e+02      9.000000      0.000000
# 50%    2.929110e+05       0.000000  7.141000e+03     18.000000      0.000000
# 75%    1.204214e+06      99.000000  5.026400e+04     32.000000      0.000000
# max    4.869723e+08  186370.000000  6.089942e+06    106.000000   2341.000000
#
#               806.0  11.291044776119403           1.0  70.49513846124168  \
# count  40948.000000        40948.000000  40948.000000       40948.000000
# mean     443.324998           55.721469     35.646381          67.464077
# std      496.698029           86.934332     69.960877          81.569243
# min        0.000000            0.000000      0.000000           0.000000
# 25%       45.000000            5.527273      2.000000           8.278756
# 50%      241.000000           23.374101     12.000000          35.069140
# 75%      717.000000           71.828829     42.000000         102.554954
# max     2341.000000         2341.000000   2341.000000         731.394558
#
#               0.0.1      ...               0.10          0.11          0.12  \
# count  40948.000000      ...       40948.000000  40948.000000  40948.000000
# mean       0.219473      ...           0.144036      0.146161      0.136930
# std       10.055268      ...           0.351131      0.353272      0.343777
# min        0.000000      ...           0.000000      0.000000      0.000000
# 25%        0.000000      ...           0.000000      0.000000      0.000000
# 50%        0.000000      ...           0.000000      0.000000      0.000000
# 75%        0.000000      ...           0.000000      0.000000      0.000000
# max     1923.000000      ...           1.000000      1.000000      1.000000
#
#                0.13          0.14          0.15          0.16          0.17  \
# count  40948.000000  40948.000000  40948.000000  40948.000000  40948.000000
# mean       0.141643      0.132510      0.137638      0.148603      0.150850
# std        0.348688      0.339048      0.344524      0.355701      0.357907
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                0.18           1.2
# count  40948.000000  40948.000000
# mean       0.143890      0.144867
# std        0.350982      0.351971
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max        1.000000      1.000000
#
# [8 rows x 53 columns]

# %%
target1.describe()
# Out:
#                 1.3
# count  10043.000000
# mean      29.243254
# std      115.038804
# min        0.000000
# 25%        0.000000
# 50%        2.000000
# 75%       13.000000
# max     2412.000000
