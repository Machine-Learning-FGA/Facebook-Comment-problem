# %% [markdown]
# # Bibliotecas para manipulação dos dados

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %% [markdown]
# # Leitura de dados

# %%
general_data = pd.read_csv('all-census-data/all.csv')

# %%
general_data.head()
# Out:
#    Unnamed: 0   State                                           District  \
# 0           1      AN  District Andamans (01), Andaman & Nicobar Isla...
# 1           2      AN  District Nicobars (02), Andaman & Nicobar Isla...
# 2           3  Andhra        District Adilabad (01), Andhra Pradesh (28)
# 3           4  Andhra       District Nizamabad (02), Andhra Pradesh (28)
# 4           5  Andhra      District Karimnagar (03), Andhra Pradesh (28)
#
#    Persons    Males  Females  Growth..1991...2001.    Rural   Urban  \
# 0   314084   170319   143765                 30.14   197886  116198
# 1    42068    22653    19415                  7.19    42068       -
# 2  2488003  1250958  1237045                 19.06  1827986     NaN
# 3  2345685  1162905  1182780                 14.98  1920947     NaN
# 4  3491822  1747968  1743854                 14.47  2813010     NaN
#
#   Scheduled.Caste.population       ...        Medical.facility  \
# ...

# %%
general_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590 entries, 0 to 589
# Data columns (total 82 columns):
# Unnamed: 0                                590 non-null int64
# State                                     590 non-null object
# District                                  590 non-null object
# Persons                                   590 non-null int64
# Males                                     590 non-null int64
# Females                                   590 non-null int64
# Growth..1991...2001.                      590 non-null float64
# Rural                                     590 non-null object
# Urban                                     68 non-null object
# Scheduled.Caste.population                27 non-null object
# Percentage...SC.to.total                  28 non-null object
# Number.of.households                      587 non-null float64
# Household.size..per.household.            587 non-null float64
# ...

# %%
general_data.describe()
# Out:
#        Unnamed: 0       Persons         Males       Females  \
# count  590.000000  5.900000e+02  5.900000e+02  5.900000e+02
# mean   295.500000  1.732902e+06  8.966605e+05  8.362419e+05
# std    170.462606  1.329998e+06  6.934142e+05  6.381679e+05
# min      1.000000  3.139400e+04  1.589300e+04  1.478300e+04
# 25%    148.250000  8.127185e+05  4.207508e+05  3.890438e+05
# 50%    295.500000  1.487712e+06  7.706160e+05  7.133320e+05
# 75%    442.750000  2.395986e+06  1.248934e+06  1.142946e+06
# max    590.000000  9.610788e+06  4.916370e+06  4.694418e+06
#
#        Growth..1991...2001.  Number.of.households  \
# count            590.000000          5.870000e+02
# mean              22.493119          3.258233e+05
# std               11.294956          2.666372e+05
# min               -3.500000          6.054000e+03
# 25%               15.352500          1.559300e+05
# 50%               21.830000          2.686090e+05
# 75%               27.147500          4.337020e+05
# ...

# %%
del general_data

# %%
AndhraPradesh_data = pd.read_csv('all-census-data/AndhraPradesh.csv')

# %%
AndhraPradesh_data.head()
# Out:
#       Year       Description  Adilabad  Anantapur  Chittoor  Godavari East  \
# 0  2004-05  GDP (in Rs. Cr.)   6527.41    9286.21   9048.39       17289.90
# 1  2005-06  GDP (in Rs. Cr.)   7058.60   10047.71  10390.13       16827.15
# 2  2006-07  GDP (in Rs. Cr.)   8300.56   11252.83  11594.82       20208.88
# 3  2007-08  GDP (in Rs. Cr.)   9860.16   15937.45  14241.18       24081.05
# 4  2008-09  GDP (in Rs. Cr.)  12342.93   17713.73  15998.11       27446.05
#
#    Godavari West    Guntur  Hyderabad    Kadapa    ...        Medak  Nalgonda  \
# 0       12704.42  11878.60   16932.79   6287.94    ...      8906.57   7658.54
# 1       12791.82  14374.44   20523.91   7050.27    ...     10613.40   9047.11
# 2       14156.37  16183.82   25016.85  12448.79    ...     13879.77  10423.51
# 3       17473.10  19125.08   30038.38  14393.29    ...     14716.18  14736.51
# 4       18552.27  22550.47   35536.76  11911.79    ...     18732.63  18346.31
#
# ...

# %%
AndhraPradesh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 25 columns):
# Year             17 non-null object
# Description      17 non-null object
# Adilabad         17 non-null float64
# Anantapur        17 non-null float64
# Chittoor         17 non-null float64
# Godavari East    17 non-null float64
# Godavari West    17 non-null float64
# Guntur           17 non-null float64
# Hyderabad        17 non-null float64
# Kadapa           17 non-null float64
# Karimnagar       17 non-null float64
# Khammam          17 non-null float64
# Krishna          17 non-null float64
# Kurnool          17 non-null float64
# Mahabubnagar     17 non-null float64
# Medak            17 non-null float64
# Nalgonda         17 non-null float64
# Nellore          17 non-null float64
# Nizambad         17 non-null float64
# Prakasam         17 non-null float64
# Rangareddy       17 non-null float64
# Srikakulam       17 non-null float64
# ...

# %%
AndhraPradesh_data.describe()
# Out:
#            Adilabad     Anantapur      Chittoor  Godavari East  Godavari West  \
# count     17.000000     17.000000     17.000000      17.000000      17.000000
# mean    6528.209412   9399.548235   9337.955294   14992.320588   11352.292941
# std     7166.187165  10360.310160  10500.846271   16079.114147   12505.344652
# min        4.980000      5.270000     10.190000      -2.680000       0.690000
# 25%       17.590000     13.900000     14.830000      14.650000      15.520000
# 50%     6527.410000   9286.210000   9048.390000   16827.150000   12704.420000
# 75%    12342.930000  17713.730000  15998.110000   27446.050000   18552.270000
# max    19641.000000  29133.000000  30593.000000   44254.000000   35456.000000
#
#              Guntur     Hyderabad        Kadapa    Karimnagar       Khammam  \
# count     17.000000     17.000000     17.000000     17.000000     17.000000
# mean   12896.259412  19594.041176   7194.292941  10069.925294   8061.542941
# ...

# %%
del AndhraPradesh_data

# %%
Assam_data = pd.read_csv('all-census-data/Assam.csv')

# %%
Assam_data.head()
# Out:
#       Year       Description     Baksa   Barpeta Bongaigaon    Cachar  \
# 0  2009-10  GDP (in Rs. Cr.)  2,060.20  3,175.96   2,627.39  4,620.81
#
#     Chirang   Darrang   Dhemaji    Dhubri    ...    Karimganj Kokrajhar  \
# 0  1,040.84  2,427.47  1,401.33  2,729.46    ...     3,278.82  2,957.87
#
#   Lakhimpur  Morigaon    Nagaon   Nalbari Sivasagar  Sonitpur  Tinsukia  \
# 0  2,535.25  2,141.58  5,035.64  2,258.00  6,749.67  4,309.46  6,109.28
#
#    Udalguri
# 0  2,151.04
#
# [1 rows x 29 columns]

# %%
Assam_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 29 columns):
# Year                     1 non-null object
# Description              1 non-null object
# Baksa                    1 non-null object
# Barpeta                  1 non-null object
# Bongaigaon               1 non-null object
# Cachar                   1 non-null object
# Chirang                  1 non-null object
# Darrang                  1 non-null object
# Dhemaji                  1 non-null object
# Dhubri                   1 non-null object
# Dibrugarh                1 non-null object
# Dima Hasao               1 non-null object
# Goalpara                 1 non-null object
# Golaghat                 1 non-null object
# Hailakandi               1 non-null object
# Jorhat                   1 non-null object
# Kamrup (Metropolitan)    1 non-null object
# Kamrup Rural             1 non-null object
# Karbi-Anglong            1 non-null object
# ...

# %%
Assam_data.describe()
# Out:
#            Year       Description     Baksa   Barpeta Bongaigaon    Cachar  \
# count         1                 1         1         1          1         1
# unique        1                 1         1         1          1         1
# top     2009-10  GDP (in Rs. Cr.)  2,060.20  3,175.96   2,627.39  4,620.81
# freq          1                 1         1         1          1         1
#
#          Chirang   Darrang   Dhemaji    Dhubri    ...    Karimganj Kokrajhar  \
# count          1         1         1         1    ...            1         1
# unique         1         1         1         1    ...            1         1
# top     1,040.84  2,427.47  1,401.33  2,729.46    ...     3,278.82  2,957.87
# freq           1         1         1         1    ...            1         1
#
#        Lakhimpur  Morigaon    Nagaon   Nalbari Sivasagar  Sonitpur  Tinsukia  \
# count          1         1         1         1         1         1         1
# ...

# %%
del Assam_data

# %%
Bihar_data = pd.read_csv('all-census-data/Bihar.csv')

# %%
Bihar_data.head()
# Out:
#       Year       Description    Araria   Arwal Aurangabad     Banka Begusarai  \
# 0  2004-05  GDP (in Rs. Cr.)  1,369.80  334.21   1,346.64  1,042.12  2,826.24
# 1  2005-06  GDP (in Rs. Cr.)  1,516.18  385.42   1,427.13  1,087.17  2,796.49
# 2  2006-07  GDP (in Rs. Cr.)  1,710.97  460.96   1,869.33  1,349.83  3,285.05
# 3  2007-08  GDP (in Rs. Cr.)  2,006.84  520.75   2,136.41  1,500.11  3,956.50
# 4  2008-09  GDP (in Rs. Cr.)  2,452.29  630.28   2,469.87  1,847.26  5,304.32
#
#     Bhabhua Bhagalpur   Bhojpur      ...         Saharsa Samstipur     Saran  \
# 0    905.22  2,586.08  1,619.35      ...        1,247.58  2,369.58  2,142.28
# 1  1,007.40  2,884.94  1,883.07      ...        1,309.20  2,519.01  2,442.83
# 2  1,180.96  3,401.79  2,311.43      ...        1,534.04  3,401.66  2,783.96
# 3  1,387.00  3,890.47  2,647.77      ...        1,709.78  3,391.63  3,274.98
# 4  1,737.32  4,726.28  3,400.49      ...        2,056.46  4,340.16  3,805.83
#
# ...

# %%
Bihar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 40 columns):
# Year              13 non-null object
# Description       13 non-null object
# Araria            13 non-null object
# Arwal             13 non-null float64
# Aurangabad        13 non-null object
# Banka             13 non-null object
# Begusarai         13 non-null object
# Bhabhua           13 non-null object
# Bhagalpur         13 non-null object
# Bhojpur           13 non-null object
# Buxar             13 non-null object
# Darbhanga         13 non-null object
# East Champaran    13 non-null object
# Gaya              13 non-null object
# Gopalgang         13 non-null object
# Jamui             13 non-null object
# Jehanabad         13 non-null object
# Katihar           13 non-null object
# Khagaria          13 non-null object
# Kishangang        13 non-null object
# Lakhisarai        13 non-null object
# Madhepura         13 non-null object
# ...

# %%
Bihar_data.describe()
# Out:
#             Arwal   Shekhpura     Sheohar
# count   13.000000   13.000000   13.000000
# mean   306.620769  308.982308  232.086154
# std    307.888844  311.076362  230.557644
# min     11.640000    3.720000   -1.840000
# 25%     19.600000   19.480000   22.260000
# 50%    334.210000  314.780000  249.520000
# 75%    520.750000  539.280000  413.080000
# max    849.500000  833.860000  650.180000

# %%
del Bihar_data

# %%
hlpca_colnames_data = pd.read_csv('all-census-data/hlpca-colnames.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-34-980d23caecfd> in <module>()
# ----> 1 hlpca_colnames = pd.read_csv('all-census-data/hlpca-colnames.csv')
#
# ...

# %%
hlpca_colnames_data.head()

# %%
hlpca_colnames_data.info()

# %%
hlpca_colnames_data.describe()

# %%
del hlpca_colnames_data

# %%
india_census_housing_hlpca_full_data = pd.read_csv('all-census-data/india_census_housing-hlpca-full.csv')

# %%
india_census_housing_hlpca_full_data.head()
# Out:
#    State Code       State Name  District Code District Name  Tehsil Code  \
# 0           1  JAMMU & KASHMIR              1       Kupwara            0
# 1           1  JAMMU & KASHMIR              1       Kupwara            0
# 2           1  JAMMU & KASHMIR              1       Kupwara            0
# 3           1  JAMMU & KASHMIR              2        Badgam            0
# 4           1  JAMMU & KASHMIR              2        Badgam            0
#
#   Tehsil Name  Town Code/Village code  Ward No           Area Name  \
# 0     Kupwara                       0        0  District - Kupwara
# 1     Kupwara                       0        0  District - Kupwara
# 2     Kupwara                       0        0  District - Kupwara
# 3      Badgam                       0        0   District - Badgam
# 4      Badgam                       0        0   District - Badgam
#
#   Rural/Urban         ...          Contition_T_Total  Contition_T_Good  \
# ...

# %%
india_census_housing_hlpca_full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Columns: 156 entries, State Code to Residence_cum_Good
# dtypes: float64(142), int64(9), object(5)
# memory usage: 2.3+ MB

# %%
india_census_housing_hlpca_full_data.describe()
# Out:
#         State Code  District Code  Tehsil Code  Town Code/Village code  \
# count  1908.000000    1908.000000       1908.0                  1908.0
# mean     17.088050     320.066038          0.0                     0.0
# std       9.392094     184.280200          0.0                     0.0
# min       1.000000       1.000000          0.0                     0.0
# 25%       9.000000     161.000000          0.0                     0.0
# 50%      18.000000     320.000000          0.0                     0.0
# 75%      24.000000     479.000000          0.0                     0.0
# max      35.000000     640.000000          0.0                     0.0
#
#        Ward No  Total Number of households  Total Number of Good  \
# count   1908.0                      1908.0           1908.000000
# mean       0.0                       100.0             53.694209
# std        0.0                         0.0             14.925468
# min        0.0                       100.0             11.500000
# ...

# %%
del india_census_housing_hlpca_full_data

# %%
india_districts_census_data = pd.read_csv('all-census-data/india-districts-census-2011.csv')

# %%
india_districts_census_data.head()
# Out:
#    District code         State Name District name  Population    Male  Female  \
# 0              1  JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1              2  JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2              3  JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3              4  JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4              5  JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC         ...          \
# 0    439654         282823           156831  1048         ...
# 1    335649         207741           127908   368         ...
# 2     93770          62834            30936   488         ...
# 3     86236          56301            29935    18         ...
# 4    261724         163333            98391   556         ...
#
#    Power_Parity_Rs_90000_150000  Power_Parity_Rs_45000_150000  \
# ...

# %%
india_districts_census_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Columns: 118 entries, District code to Total_Power_Parity
# dtypes: int64(116), object(2)
# memory usage: 590.1+ KB

# %%
india_districts_census_data.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate            SC       Male_SC  \
# count   6.400000e+02     6.400000e+02  6.400000e+02  6.400000e+02
# mean    6.793182e+05     5.138675e+05  3.146537e+05  1.617739e+05
# std     5.924144e+05     4.801816e+05  3.129818e+05  1.611216e+05
# ...

# %%
del india_districts_census_data

# %%
karnataka_data = pd.read_csv('all-census-data/karnataka.csv')

# %%
karnataka_data.head()
# Out:
#       Year          Description Bagalkote Bangalore Rural Bangalore Urban  \
# 0  2007-08     GDP (in Rs. Cr.)     5,903           5,739          90,753
# 1  2008-09     GDP (in Rs. Cr.)     6,521           6,332        1,02,183
# 2  2009-10     GDP (in Rs. Cr.)     6,633           9,039        1,17,356
# 3  2010-11     GDP (in Rs. Cr.)     8,146          10,278        1,28,197
# 4  2008-09  Growth Rate % (YoY)     10.47           10.33           12.59
#
#   Belgaum Bellary  Bidar Bijapur Chamarajanagar   ...    Koppal Mandya  \
# 0  14,704  12,350  3,829   5,721          2,778   ...     3,679  5,322
# 1  16,205  13,317  4,288   6,348         30,409   ...     4,037  5,829
# 2  18,868  13,454  4,645   6,480          3,229   ...     4,533  5,828
# 3  22,297  19,498  6,006   8,828          3,757   ...     5,863  7,497
# 4   10.21    7.83  11.99   10.96         994.64   ...      9.73   9.53
#
#    Mysore Raichur Ramnagara Shimoga  Tumkur  Udupi Uttara Kannads Yadagiri
# ...

# %%
karnataka_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 32 columns):
# Year                7 non-null object
# Description         7 non-null object
# Bagalkote           7 non-null object
# Bangalore Rural     7 non-null object
# Bangalore Urban     7 non-null object
# Belgaum             7 non-null object
# Bellary             7 non-null object
# Bidar               7 non-null object
# Bijapur             7 non-null object
# Chamarajanagar      7 non-null object
# Chickballapur       7 non-null object
# Chickmagalur        7 non-null object
# Chitradurga         7 non-null object
# Dakshina Kannada    7 non-null object
# Davangere           7 non-null object
# Dharwad             7 non-null object
# Gadag               7 non-null object
# Gulbarga            7 non-null object
# Hassan              7 non-null object
# Haveri              7 non-null object
# Kodagu              7 non-null object
# Kolar               7 non-null object
# ...

# %%
karnataka_data.describe()
# Out:
#            Year       Description Bagalkote Bangalore Rural Bangalore Urban  \
# count         7                 7         7               7               7
# unique        4                 2         7               7               7
# top     2010-11  GDP (in Rs. Cr.)     6,633           42.75           12.59
# freq          2                 4         1               1               1
#
#        Belgaum Bellary  Bidar Bijapur Chamarajanagar   ...    Koppal Mandya  \
# count        7       7      7       7              7   ...         7      7
# unique       7       7      7       7              7   ...         7      7
# top      18.17    1.03  4,288   6,480          2,778   ...     5,863   9.53
# freq         1       1      1       1              1   ...         1      1
#
#        Mysore Raichur Ramnagara Shimoga Tumkur  Udupi Uttara Kannads Yadagiri
# count       7       7         7       7      7      7              7        3
# ...

# %%
del karnataka_data

# %%
Kerala_data = pd.read_csv('all-census-data/Kerala.csv')

# %%
Kerala_data.head()
# Out:
#       Year       Description  Alappuzha  Eranakulam   Idukki    Kannur  \
# 0  2004-05  GDP (in Rs. Cr.)    7610.28    16681.12  4466.65   8640.83
# 1  2005-06  GDP (in Rs. Cr.)    8780.71    19158.99  5090.36   9953.32
# 2  2006-07  GDP (in Rs. Cr.)    9975.10    21902.69  5639.35  10952.44
# 3  2007-08  GDP (in Rs. Cr.)   11308.12    25082.24  6101.25  12460.44
# 4  2008-09  GDP (in Rs. Cr.)   13240.20    29592.35  7302.45  14414.58
#
#    Kasaragod    Kollam  Kottayam  Kozhikode  Malappuram  Palakkad  \
# 0    3995.04   8853.74   8225.77   10257.75     9592.94   9266.39
# 1    4487.04  10403.22   9603.85   11796.17    10956.76  10332.08
# 2    5079.01  11555.24  10843.13   13331.81    12011.96  11902.49
# 3    5892.13  13176.85  12350.36   15170.56    13657.16  13687.63
# 4    6283.10  15964.57  14032.46   17474.07    16470.52  15232.42
#
#    Pathanamthitta  Thiruvananthapuram  Thrissur  Wayanad
# 0         4630.16            12845.27  11391.85  2806.21
# ...

# %%
Kerala_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 16 columns):
# Year                  17 non-null object
# Description           17 non-null object
# Alappuzha             17 non-null float64
# Eranakulam            17 non-null float64
# Idukki                17 non-null float64
# Kannur                17 non-null float64
# Kasaragod             17 non-null float64
# Kollam                17 non-null float64
# Kottayam              17 non-null float64
# Kozhikode             17 non-null float64
# Malappuram            17 non-null float64
# Palakkad              17 non-null float64
# Pathanamthitta        17 non-null float64
# Thiruvananthapuram    17 non-null float64
# Thrissur              17 non-null float64
# Wayanad               17 non-null float64
# dtypes: float64(14), object(2)
# memory usage: 2.2+ KB

# %%
Kerala_data.describe()
# Out:
#           Alappuzha    Eranakulam        Idukki        Kannur     Kasaragod  \
# count     17.000000     17.000000     17.000000     17.000000     17.000000
# mean    7345.770588  16186.571176   4246.007059   8213.546471   3714.808235
# std     7952.403326  17575.721322   4631.910942   8947.273312   4035.427209
# min        7.800000     11.220000      8.190000     10.040000      6.640000
# 25%       15.380000     14.850000     13.960000     14.790000     13.510000
# 50%     7610.280000  16681.120000   4466.650000   8640.830000   3995.040000
# 75%    13240.200000  29592.350000   7302.450000  14414.580000   6283.100000
# max    22283.580000  49453.290000  12768.890000  25346.440000  11522.960000
#
#              Kollam      Kottayam     Kozhikode    Malappuram      Palakkad  \
# count     17.000000     17.000000     17.000000     17.000000     17.000000
# mean    8671.562353   8000.609412   9846.007059   8998.190588   8852.957059
# ...

# %%
del Kerala_data

# %%
Maharashtra_data = pd.read_csv('all-census-data/Maharashtra.csv')

# %%
Maharashtra_data.head()
# Out:
#       Year       Description  Ahmednagar   Akola  Amravati  Aurangabad  \
# 0  2005-06  GDP (in Rs. Cr.)     14105.0  4589.0    7119.0     11303.0
# 1  2006-07  GDP (in Rs. Cr.)     17134.0  5744.0    8081.0     13174.0
# 2  2007-08  GDP (in Rs. Cr.)     20284.0  6878.0   10074.0     15959.0
# 3  2008-09  GDP (in Rs. Cr.)     23708.0  8520.0   12616.0     22468.0
# 4  2009-10  GDP (in Rs. Cr.)     24053.0  9717.0   15725.0     26610.0
#
#       Beed  Bhandara  Buldhana  Chandrapur    ...      Raigad  Ratnagiri  \
# 0   5708.0    3784.0    4851.0      8424.0    ...     11971.0     6045.0
# 1   6743.0    4301.0    5779.0      8936.0    ...     13823.0     6798.0
# 2   8175.0    5322.0    7378.0     10519.0    ...     16399.0     8292.0
# 3   9079.0    6541.0    9315.0     12451.0    ...     21417.0     9583.0
# 4  10124.0    6392.0   10093.0     14676.0    ...     22950.0    11771.0
#
#     Sangli   Satara  Sindhudurg  Solapur     Thane   Wahim  Wardha  Yavatmal
# ...

# %%
Maharashtra_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 36 columns):
# Year           15 non-null object
# Description    15 non-null object
# Ahmednagar     15 non-null float64
# Akola          15 non-null float64
# Amravati       15 non-null float64
# Aurangabad     15 non-null float64
# Beed           15 non-null float64
# Bhandara       15 non-null float64
# Buldhana       15 non-null float64
# Chandrapur     15 non-null float64
# Dhule          15 non-null float64
# Gadchiroli     15 non-null float64
# Gondia         15 non-null float64
# Hingoli        15 non-null float64
# Jalgaon        15 non-null float64
# Jalna          15 non-null float64
# Kolhapur       15 non-null float64
# Latur          15 non-null float64
# Mumbai         15 non-null float64
# Nagpur         15 non-null float64
# Nanded         15 non-null float64
# Nandurbar      15 non-null float64
# Nashik         15 non-null float64
# Osmanabad      15 non-null float64
# ...

# %%
Maharashtra_data.describe()
# Out:
#          Ahmednagar         Akola      Amravati    Aurangabad          Beed  \
# count     15.000000     15.000000     15.000000     15.000000     15.000000
# mean   13728.500000   5001.524000   7714.586667  12739.677333   5449.017333
# std    14688.428759   5465.748446   8563.423104  14085.555114   5782.188038
# min        1.460000      9.250000      6.820000      7.410000      5.380000
# 25%       17.630000     19.650000     22.560000     18.185000     14.820000
# 50%    14105.000000   4589.000000   7119.000000  11303.000000   5708.000000
# 75%    23880.500000   9118.500000  14170.500000  24539.000000   9601.500000
# max    38710.000000  15133.000000  23770.000000  36367.000000  14689.000000
#
#           Bhandara      Buldhana    Chandrapur         Dhule   Gadchiroli  \
# count    15.000000     15.000000     15.000000     15.000000    15.000000
# mean   3437.494000   5352.240667   7683.867333   5094.931333  2181.210667
# ...

# %%
del Maharashtra_data

# %%
Odisha_data = pd.read_csv('all-census-data/Odisha.csv')

# %%
Odisha_data.head()
# Out:
#       Year       Description      Angul  Balangir  Balasore   Bargarh  \
# 0  2004-05  GDP (in Rs. Cr.)   5,690.79  2,430.39  3,251.17  2,045.07
# 1  2005-06  GDP (in Rs. Cr.)   5,968.06  2,648.19  3,510.89  2,216.28
# 2  2006-07  GDP (in Rs. Cr.)   6,982.18  3,151.62  4,214.05  2,597.66
# 3  2007-08  GDP (in Rs. Cr.)   8,916.88  4,068.88  5,410.40  3,292.48
# 4  2008-09  GDP (in Rs. Cr.)  10,473.35  4,506.90  6,141.29  3,791.29
#
#     Bhadrak     Boudh   Cuttack Deogarh    ...     Malkangiri Mayurbhanj  \
# 0  1,855.46    642.51  5,756.75   477.6    ...          808.6   3,378.09
# 1  2,017.33     732.4  6,030.83  537.59    ...         825.25   3,632.53
# 2  2,341.49    863.23  7,116.92  628.84    ...          997.3   4,279.41
# 3  2,918.65  1,112.53  8,636.41  753.26    ...       1,257.93   5,479.57
# 4  3,323.91  1,196.99  9,837.16  851.03    ...       1,311.60   6,117.11
#
#   Nabarangpur Nayargarh   Nuapada      Puri  Rayagada Sambalpur Subarnapur  \
# ...

# %%
Odisha_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 32 columns):
# Year             13 non-null object
# Description      13 non-null object
# Angul            13 non-null object
# Balangir         13 non-null object
# Balasore         13 non-null object
# Bargarh          13 non-null object
# Bhadrak          13 non-null object
# Boudh            13 non-null object
# Cuttack          13 non-null object
# Deogarh          13 non-null object
# Dhenkanal        13 non-null object
# Gajapati         13 non-null object
# Ganjam           13 non-null object
# Jagatsinghpur    13 non-null object
# Jajpur           13 non-null object
# Jharsuguda       13 non-null object
# Kalahandi        13 non-null object
# Kandhamal        13 non-null object
# Kendrapara       13 non-null object
# Kendujhar        13 non-null object
# Khordha          13 non-null object
# Koraput          13 non-null object
# Malkangiri       13 non-null object
# ...

# %%
Odisha_data.describe()
# Out:
#            Year       Description Angul  Balangir  Balasore Bargarh   Bhadrak  \
# count        13                13    13        13        13      13        13
# unique        7                 2    13        13        13      13        13
# top     2010-11  GDP (in Rs. Cr.)  1.23  4,506.90  4,214.05   11.49  3,852.89
# freq          2                 7     1         1         1       1         1
#
#        Boudh Cuttack Deogarh    ...     Malkangiri Mayurbhanj Nabarangpur  \
# count     13      13      13    ...             13         13          13
# unique    13      13      13    ...             13         13          13
# top     14.5    4.76  628.84    ...           4.27      28.04        12.5
# freq       1       1       1    ...              1          1           1
#
#        Nayargarh Nuapada   Puri Rayagada Sambalpur Subarnapur Sundargarh
# count         13      13     13       13        13         13         13
# ...

# %%
del Odisha_data

# %%
Punjab_data = pd.read_csv('all-census-data/Punjab.csv')

# %%
Punjab_data.head()
# Out:
#       Year       Description   Amritsar   Barnala  Bathinda  Faridkot  \
# 0  2004-05  GDP (in Rs. Cr.)  11,364.41       NaN  4,271.16  2,161.56
# 1  2005-06  GDP (in Rs. Cr.)  12,518.66       NaN  4,854.69  2,458.49
# 2  2006-07  GDP (in Rs. Cr.)  10,051.98       NaN  5,686.30  2,861.00
# 3  2007-08  GDP (in Rs. Cr.)  11,206.59  3,247.54  6,879.18  3,334.75
# 4  2008-09  GDP (in Rs. Cr.)  12,932.01  3,701.16  7,917.27  4,004.00
#
#   Fatehgarh Sahib  Firozepur  Gurdaspur Hoshiarpur    ...       Ludhiana  \
# 0        2,467.97   6,248.08   6,662.55   5,317.82    ...      14,740.80
# 1        2,766.16   7,072.82   7,618.49   5,890.04    ...      16,731.23
# 2        3,104.92   8,152.10   8,756.99   7,042.67    ...      19,702.44
# 3        3,812.18   9,590.00  10,319.26   8,098.41    ...      23,941.44
# 4        4,253.53  11,352.54  12,051.58   9,242.03    ...      26,970.35
#
#       Mansa      Moga   Muktsar    Patiala Roopnagar  \
# ...

# %%
Punjab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 22 columns):
# Year                          13 non-null object
# Description                   13 non-null object
# Amritsar                      13 non-null object
# Barnala                       7 non-null object
# Bathinda                      13 non-null object
# Faridkot                      13 non-null object
# Fatehgarh Sahib               13 non-null object
# Firozepur                     13 non-null object
# Gurdaspur                     13 non-null object
# Hoshiarpur                    13 non-null object
# Jalandhar                     13 non-null object
# Kapurthala                    13 non-null object
# Ludhiana                      13 non-null object
# Mansa                         13 non-null object
# Moga                          13 non-null object
# Muktsar                       13 non-null object
# Patiala                       13 non-null object
# ...

# %%
Punjab_data.describe()
# Out:
#            Year       Description   Amritsar   Barnala  Bathinda  Faridkot  \
# count        13                13         13         7        13        13
# unique        7                 2         13         7        13        13
# top     2010-11  GDP (in Rs. Cr.)  14,604.45  3,701.16  8,727.05  2,861.00
# freq          2                 7          1         1         1         1
#
#        Fatehgarh Sahib  Firozepur  Gurdaspur Hoshiarpur    ...     Ludhiana  \
# count               13         13         13         13    ...           13
# unique              13         13         13         13    ...           13
# top           2,467.97  12,451.43  10,319.26   5,317.82    ...        12.77
# freq                 1          1          1          1    ...            1
#
#            Mansa      Moga   Muktsar Patiala Roopnagar  \
# count         13        13        13      13        13
# unique        13        13        13      13        13
# ...

# %%
del Punjab_data

# %%
Rajasthan_data = pd.read_csv('all-census-data/Rajasthan.csv')

# %%
Rajasthan_data.head()
# Out:
#       Year       Description      Ajmer      Alwar  Banswara     Baran  \
# 0  2004-05  GDP (in Rs. Cr.)   5,493.87   7,742.03  2,421.88  2,729.69
# 1  2005-06  GDP (in Rs. Cr.)   6,832.92   8,196.52  2,423.48  3,061.58
# 2  2006-07  GDP (in Rs. Cr.)   8,493.64  10,341.88  2,627.03  3,267.05
# 3  2007-08  GDP (in Rs. Cr.)   9,507.25  11,600.91  3,144.06  4,330.68
# 4  2008-09  GDP (in Rs. Cr.)  10,520.55  14,742.95  3,430.45  4,661.14
#
#      Barmer Bharatpur   Bhilwara   Bikaner    ...          Kota    Nagaur  \
# 0  3,213.20  3,643.34   6,255.18  4,160.15    ...      4,564.14  4,836.34
# 1  3,494.49  4,164.97   6,122.12  4,356.38    ...      4,954.54  5,424.59
# 2  4,204.65  4,877.25   8,250.67  5,213.55    ...      5,886.79  6,130.03
# 3  5,022.84  5,429.47   8,846.04  6,126.30    ...      7,263.36  7,075.78
# 4  5,621.95  6,308.93  11,286.77  7,496.54    ...      8,139.47  8,774.97
#
#        Pali Pratapgarh Rajsamand Sawai Madhopur     Sikar    Sirohi      Tonk  \
# ...

# %%
Rajasthan_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 35 columns):
# Year              11 non-null object
# Description       11 non-null object
# Ajmer             11 non-null object
# Alwar             11 non-null object
# Banswara          11 non-null object
# Baran             11 non-null object
# Barmer            11 non-null object
# Bharatpur         11 non-null object
# Bhilwara          11 non-null object
# Bikaner           11 non-null object
# Bundi             11 non-null object
# Chittorgarh       11 non-null object
# Churu             11 non-null object
# Dausa             11 non-null object
# Dholpur           11 non-null object
# Dungarpur         11 non-null object
# Ganga Nagar       11 non-null object
# Hanumangarh       11 non-null object
# Jaipur            11 non-null object
# Jaisalmer         11 non-null object
# Jalore            11 non-null object
# Jhalawar          11 non-null object
# ...

# %%
Rajasthan_data.describe()
# Out:
#            Year       Description      Ajmer      Alwar Banswara  Baran  \
# count        11                11         11         11       11     11
# unique        6                 2         11         11       11     11
# top     2008-09  GDP (in Rs. Cr.)  10,520.55  11,600.91     14.3  32.56
# freq          2                 6          1          1        1      1
#
#           Barmer Bharatpur  Bhilwara   Bikaner    ...      Kota Nagaur  Pali  \
# count         11        11        11        11    ...        11     11    11
# unique        11        11        11        11    ...        11     11    11
# top     3,494.49  5,429.47  6,255.18  5,213.55    ...     12.06  24.01  5.44
# freq           1         1         1         1    ...         1      1     1
#
#        Pratapgarh Rajsamand Sawai Madhopur     Sikar Sirohi      Tonk  \
# count           3        11             11        11     11        11
# unique          3        11             11        11     11        11
# ...

# %%
del Rajasthan_data

# %%
UttarPradesh_data = pd.read_csv('all-census-data/UttarPradesh.csv')

# %%
UttarPradesh_data.head()
# Out:
#       Year       Description       Agra   Aligarh  Allahabad Ambedkar Nagar  \
# 0  2004-05  GDP (in Rs. Cr.)   7,047.44  5,114.33   6,955.02       1,830.48
# 1  2005-06  GDP (in Rs. Cr.)   8,113.95  6,240.52   8,977.85       2,351.66
# 2  2006-07  GDP (in Rs. Cr.)   9,399.58  7,240.47   9,990.30       2,627.90
# 3  2007-08  GDP (in Rs. Cr.)  10,463.18  8,147.22  11,977.87       3,118.18
# 4  2008-09  GDP (in Rs. Cr.)  11,932.70  9,324.46  13,703.33       3,645.23
#
#   Amethi    Amorha  Auraiyya  Azamgarh    ...    Sant kabeer Maharaj Ganj  \
# 0    NaN  3,462.80  1,417.47  3,157.37    ...                    1,125.05
# 1    NaN  3,848.40  1,764.91  4,248.85    ...                    1,487.48
# 2    NaN  4,002.50  2,084.93  4,847.00    ...                    1,443.30
# 3    NaN  4,478.46  2,644.94  5,096.94    ...                    1,696.41
# 4    NaN  5,444.81  3,132.84  5,921.09    ...                    2,034.30
#
# ...

# %%
UttarPradesh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 74 columns):
# Year                        15 non-null object
# Description                 15 non-null object
# Agra                        15 non-null object
# Aligarh                     15 non-null object
# Allahabad                   15 non-null object
# Ambedkar Nagar              15 non-null object
# Amethi                      3 non-null object
# Amorha                      15 non-null object
# Auraiyya                    15 non-null object
# Azamgarh                    15 non-null object
# Badaun                      15 non-null object
# Bagpat                      15 non-null object
# Bahraich                    15 non-null object
# Ballia                      15 non-null object
# Balrampur                   15 non-null object
# Banda                       15 non-null object
# Barabanki                   15 non-null object
# Bareilly                    15 non-null object
# ...

# %%
UttarPradesh_data.describe()
# Out:
#            Year       Description   Agra Aligarh Allahabad Ambedkar Nagar  \
# count        15                15     15      15        15             15
# unique        8                 2     15      15        15             15
# top     2010-11  GDP (in Rs. Cr.)  11.32   16.02      7.76           16.9
# freq          2                 8      1       1         1              1
#
#           Amethi Amorha Auraiyya  Azamgarh    ...    Sant kabeer Maharaj Ganj  \
# count          3     15       15        15    ...                          15
# unique         3     15       15        15    ...                          15
# top     4,285.24  11.89    35.41  8,875.46    ...                    2,034.30
# freq           1      1        1         1    ...                           1
#
#        Sant Ravi Das Nagar Shahjahanpur Shravasti Siddharth Nagar Sitapur  \
# count                   15           15        15              15      15
# ...

# %%
del UttarPradesh_data

# %%
westbengal_data = pd.read_csv('all-census-data/westbengal.csv')

# %%
westbengal_data.head()
# Out:
#       Year       Description 24-Parganas (North) 24-Parganas (South)  \
# 0  2004-05  GDP (in Rs. Cr.)           24,416.69           16,884.94
# 1  2005-06  GDP (in Rs. Cr.)           27,833.39           18,090.46
# 2  2006-07  GDP (in Rs. Cr.)           31,332.56           21,654.50
# 3  2007-08  GDP (in Rs. Cr.)           36,277.12           24,613.43
# 4  2008-09  GDP (in Rs. Cr.)           42,657.90           27,590.50
#
#      Bankura    Birbhum    Burdwan Cooch Behar Dakshin Dinajpur Darjeeling  \
# 0   6,625.78   5,924.68  22,357.47    5,066.53         3,048.61   4,960.24
# 1   7,447.22   6,576.84  23,024.40    5,635.81         3,325.82   5,633.86
# 2   8,410.89   7,698.74  27,759.01    6,058.96         3,623.38   6,305.60
# 3   9,784.21   8,773.12  31,005.37    6,997.68         4,183.27   7,130.89
# 4  11,017.38  10,004.71  34,611.33    7,907.27         4,779.86   8,788.56
#
#        ...           Howrah Jalpaiguri    Kolkata      Malda Midnapore East  \
# ...

# %%
westbengal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 21 columns):
# Year                   13 non-null object
# Description            13 non-null object
# 24-Parganas (North)    13 non-null object
# 24-Parganas (South)    13 non-null object
# Bankura                13 non-null object
# Birbhum                13 non-null object
# Burdwan                13 non-null object
# Cooch Behar            13 non-null object
# Dakshin Dinajpur       13 non-null object
# Darjeeling             13 non-null object
# Hooghly                13 non-null object
# Howrah                 13 non-null object
# Jalpaiguri             13 non-null object
# Kolkata                13 non-null object
# Malda                  13 non-null object
# Midnapore East         13 non-null object
# Midnapore West         13 non-null object
# Murshidabad            13 non-null object
# Nadia                  13 non-null object
# Purulia                13 non-null object
# ...

# %%
westbengal_data.describe()
# Out:
#            Year       Description 24-Parganas (North) 24-Parganas (South)  \
# count        13                13                  13                  13
# unique        7                 2                  13                  13
# top     2010-11  GDP (in Rs. Cr.)               15.57           31,383.62
# freq          2                 7                   1                   1
#
#           Bankura   Birbhum    Burdwan Cooch Behar Dakshin Dinajpur  \
# count          13        13         13          13               13
# unique         13        13         13          13               13
# top     14,061.31  6,576.84  40,218.01        7.51             18.9
# freq            1         1          1           1                1
#
#        Darjeeling      ...       Howrah Jalpaiguri Kolkata      Malda  \
# count          13      ...           13         13      13         13
# unique         13      ...           13         13      13         13
# ...

# %%
del westbengal_data
