# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
lr = 2.12
lr_fr = 0.26

dt = 0.0
dt_fr = 4.47

rf = 4.68

gb = 4969.0
gb_fr = 0.0

# %%
y = [lr,lr_fr, dt, dt_fr, rf, gb, gb_fr]
x = [2.12, 0.26, 0.0, 4.47, 4.68, 4969.0, 0.0]

# %%
x = [1,2,3,4,5,6,7]

# %%
plt.xticks(np.arange(8),('0','lr','lr_fr','dt','dt_fr','rf', 'gb', 'gb_fr'))
plt.plot(x,y)
plt.show()
